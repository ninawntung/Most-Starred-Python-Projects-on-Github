# %% [markdown]
# # Most-Starred Python Projects on Github

# %% [markdown]
# ### Processing an API response

# %%
import requests

# Make an API call and store the response
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Store API response in a variable
response_dict = r.json()

# Process results
print(response_dict.keys())
# Out:
# Status code: 200
# Total repositories: 10527151
# dict_keys(['total_count', 'incomplete_results', 'items'])

# %% [markdown]
# ### Working with the Reponse Dictionary

# %%
import requests

# Make an API call and store the response
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Store API response in a variable
response_dict = r.json()
print(f"Total repositories: {response_dict['total_count']}")

# Explore information about the repositories
repo_dicts = response_dict['items']
print(f"Repositories returned : {len(repo_dicts)}")

# Examine the first repository
repo_dict = repo_dicts[0]
print(f"\nKeys: {len(repo_dict)}")

for key in sorted(repo_dict.keys()):
    print(key)
# Out:
# Status code: 200
# Total repositories: 10108177
# Repositories returned : 30
#
# Keys: 80
# allow_forking
# archive_url
# archived
# assignees_url
# blobs_url
# branches_url
# clone_url
# collaborators_url
# comments_url
# commits_url
# compare_url
# contents_url
# contributors_url
# created_at
# default_branch
# deployments_url
# description
# disabled
# downloads_url
# events_url
# fork
# forks
# forks_count
# forks_url
# full_name
# git_commits_url
# git_refs_url
# git_tags_url
# git_url
# has_discussions
# has_downloads
# has_issues
# has_pages
# has_projects
# has_wiki
# homepage
# hooks_url
# html_url
# id
# is_template
# issue_comment_url
# issue_events_url
# issues_url
# keys_url
# labels_url
# language
# languages_url
# license
# merges_url
# milestones_url
# mirror_url
# name
# node_id
# notifications_url
# open_issues
# open_issues_count
# owner
# private
# pulls_url
# pushed_at
# releases_url
# score
# size
# ssh_url
# stargazers_count
# stargazers_url
# statuses_url
# subscribers_url
# subscription_url
# svn_url
# tags_url
# teams_url
# topics
# trees_url
# updated_at
# url
# visibility
# watchers
# watchers_count
# web_commit_signoff_required

# %%
import requests

# Make an API call and store the response
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Store API response in a variable
response_dict = r.json()
print(f"Total repositories: {response_dict['total_count']}")

# Explore information about the repositories
repo_dicts = response_dict['items']
print(f"Repositories returned : {len(repo_dicts)}")

# Examine the first repository
repo_dict = repo_dicts[0]
print("\nSelected information about first repository:")
print(f"Name: {repo_dict['name']}")
print(f"Owner: {repo_dict['owner']['login']}")
print(f"Stars: {repo_dict['stargazers_count']}")
print(f"Repository: {repo_dict['html_url']}")
print(f"Created: {repo_dict['created_at']}")
print(f"Updated: {repo_dict['updated_at']}")
print(f"Description: {repo_dict['description']}")
# Out:
# Status code: 200
# Total repositories: 10314141
# Repositories returned : 30
#
# Selected information about first repository:
# Name: Python
# Owner: TheAlgorithms
# Stars: 160685
# Repository: https://github.com/TheAlgorithms/Python
# Created: 2016-07-16T09:44:01Z
# Updated: 2023-07-08T08:36:38Z
# Description: All Algorithms implemented in Python

# %% [markdown]
# ### Summarizing the Top Repositories

# %%
import requests

# Make an API call and store the response
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Store API response in a variable
response_dict = r.json()
print(f"Total repositories: {response_dict['total_count']}")

# Explore information about the repositories
repo_dicts = response_dict['items']
print(f"Repositories returned : {len(repo_dicts)}")

print("\nSelected information about each repository:")
for repo_dict in repo_dicts:
    print(f"Name: {repo_dict['name']}")
    print(f"Owner: {repo_dict['owner']['login']}")
    print(f"Stars: {repo_dict['stargazers_count']}")
    print(f"Repository: {repo_dict['html_url']}")
    print(f"Created: {repo_dict['created_at']}")
    print(f"Updated: {repo_dict['updated_at']}")
    print(f"Description: {repo_dict['description']}")
    print("\n")
# Out:
# Status code: 200
# Total repositories: 9348405
# Repositories returned : 30
#
# Selected information about each repository:
# Name: tf-coreml
# Owner: tf-coreml
# Stars: 1323
# Repository: https://github.com/tf-coreml/tf-coreml
# Created: 2017-10-11T19:57:03Z
# Updated: 2023-06-14T05:55:30Z
# Description: TensorFlow to CoreML Converter
#
#
# Name: hamms
# Owner: kevinburke
# Stars: 1220
# Repository: https://github.com/kevinburke/hamms
# Created: 2013-08-12T03:58:35Z
# Updated: 2023-06-12T17:38:36Z
# Description: Malformed servers to test your HTTP client
#
#
# Name: djangobook.com
# Owner: jacobian
# Stars: 1067
# Repository: https://github.com/jacobian/djangobook.com
# Created: 2012-09-25T00:15:55Z
# Updated: 2023-05-24T02:19:08Z
# Description: None
#
#
# Name: brumadinho_location
# Owner: sosbrumadinho
# Stars: 876
# Repository: https://github.com/sosbrumadinho/brumadinho_location
# Created: 2019-01-27T20:32:59Z
# Updated: 2023-06-03T15:14:09Z
# Description: Conjunto de ferramentas para ajudar no resgate e localização das vítimas atingidas pelo rompimento da barragem que ocorreu recentemente em Brumadinho/MG
#
#
# Name: mincss
# Owner: peterbe
# Stars: 854
# Repository: https://github.com/peterbe/mincss
# Created: 2012-12-23T19:47:17Z
# Updated: 2023-06-07T15:27:23Z
# Description: Tool for finding out which CSS selectors you're NOT using.
#
#
# Name: krill
# Owner: p-e-w
# Stars: 808
# Repository: https://github.com/p-e-w/krill
# Created: 2015-07-19T15:33:22Z
# Updated: 2023-05-01T12:22:55Z
# Description: :newspaper: The hacker's way of keeping up with the world (NO LONGER MAINTAINED)
#
#
# Name: Just-Code
# Owner: YaxeZhang
# Stars: 775
# Repository: https://github.com/YaxeZhang/Just-Code
# Created: 2019-09-04T09:50:40Z
# Updated: 2023-06-09T05:52:00Z
# Description: Just  Code ! 针对面试训练算法题， 目前包括字节跳动面试题、 LeetCode 和剑指 offer ，持续扩容中 :star:
#
#
# Name: wallproxy
# Owner: wallproxy
# Stars: 760
# Repository: https://github.com/wallproxy/wallproxy
# Created: 2012-08-26T12:11:11Z
# Updated: 2023-06-01T14:38:27Z
# Description: None
#
#
# Name: Text-Classification
# Owner: TobiasLee
# Stars: 740
# Repository: https://github.com/TobiasLee/Text-Classification
# Created: 2017-08-30T05:19:09Z
# Updated: 2023-03-22T03:44:53Z
# Description: Implementation of papers for text classification task on DBpedia
#
#
# Name: log4shell-detector
# Owner: Neo23x0
# Stars: 731
# Repository: https://github.com/Neo23x0/log4shell-detector
# Created: 2021-12-11T11:37:05Z
# Updated: 2023-06-12T00:58:25Z
# Description: Detector for Log4Shell exploitation attempts
#
#
# Name: lottery-ticket-hypothesis
# Owner: google-research
# Stars: 692
# Repository: https://github.com/google-research/lottery-ticket-hypothesis
# Created: 2018-11-02T18:39:27Z
# Updated: 2023-06-11T04:32:55Z
# Description: A reimplementation of "The Lottery Ticket Hypothesis" (Frankle and Carbin) on MNIST.
#
#
# Name: centrifuge
# Owner: FZambia
# Stars: 684
# Repository: https://github.com/FZambia/centrifuge
# Created: 2013-03-03T11:43:39Z
# Updated: 2023-05-01T06:20:48Z
# Description: Migrated to Go language, see https://github.com/centrifugal/centrifugo
#
#
# Name: sentence2vec
# Owner: klb3713
# Stars: 666
# Repository: https://github.com/klb3713/sentence2vec
# Created: 2014-07-14T12:04:33Z
# Updated: 2023-03-04T08:51:26Z
# Description: Tools for mapping a sentence with arbitrary length to vector space
#
#
# Name: dhcpwn
# Owner: mschwager
# Stars: 656
# Repository: https://github.com/mschwager/dhcpwn
# Created: 2015-12-04T00:05:52Z
# Updated: 2023-05-02T03:04:33Z
# Description: All your IPs are belong to us.
#
#
# Name: theano_exercises
# Owner: goodfeli
# Stars: 655
# Repository: https://github.com/goodfeli/theano_exercises
# Created: 2014-02-19T00:17:58Z
# Updated: 2023-06-08T20:39:35Z
# Description: Exercises for my tutorials on Theano
#
#
# Name: Keras-FCN
# Owner: aurora95
# Stars: 648
# Repository: https://github.com/aurora95/Keras-FCN
# Created: 2016-10-20T06:46:10Z
# Updated: 2023-02-27T05:32:28Z
# Description: Keras-tensorflow implementation of Fully Convolutional Networks for Semantic Segmentation（Unfinished）
#
#
# Name: dml
# Owner: justdark
# Stars: 636
# Repository: https://github.com/justdark/dml
# Created: 2013-10-25T05:41:03Z
# Updated: 2023-05-15T02:54:39Z
# Description: D's Machine Learning is a machine learning toolkit for python,focus on rightness but efficiency
#
#
# Name: dist-keras
# Owner: cerndb
# Stars: 623
# Repository: https://github.com/cerndb/dist-keras
# Created: 2016-07-25T09:47:37Z
# Updated: 2023-02-17T08:46:34Z
# Description: Distributed Deep Learning, with a focus on distributed training, using Keras and Apache Spark.
#
#
# Name: asyncmongo
# Owner: bitly
# Stars: 617
# Repository: https://github.com/bitly/asyncmongo
# Created: 2010-10-04T13:45:10Z
# Updated: 2023-01-28T16:44:20Z
# Description: An asynchronous library for accessing mongo with tornado.ioloop
#
#
# Name: dynamic-dynamodb
# Owner: sebdah
# Stars: 612
# Repository: https://github.com/sebdah/dynamic-dynamodb
# Created: 2013-02-19T10:44:06Z
# Updated: 2023-04-20T05:53:11Z
# Description: Dynamic DynamoDB provides auto scaling for AWS DynamoDB
#
#
# Name: milk
# Owner: luispedro
# Stars: 610
# Repository: https://github.com/luispedro/milk
# Created: 2009-11-20T21:17:14Z
# Updated: 2023-01-28T13:34:33Z
# Description: MILK: Machine Learning Toolkit
#
#
# Name: doorman
# Owner: mwielgoszewski
# Stars: 604
# Repository: https://github.com/mwielgoszewski/doorman
# Created: 2016-04-22T19:31:53Z
# Updated: 2023-06-13T19:26:53Z
# Description: an osquery fleet manager
#
#
# Name: crackcoin
# Owner: beurtschipper
# Stars: 600
# Repository: https://github.com/beurtschipper/crackcoin
# Created: 2017-07-09T14:56:31Z
# Updated: 2023-04-18T11:50:18Z
# Description: Very basic blockchain-free cryptocurrency PoC in Python
#
#
# Name: PFLD
# Owner: guoqiangqi
# Stars: 598
# Repository: https://github.com/guoqiangqi/PFLD
# Created: 2019-05-21T02:28:57Z
# Updated: 2023-05-02T10:58:06Z
# Description: Implementation of PFLD A Practical Facial Landmark Detector  , reference to  https://arxiv.org/pdf/1902.10859.pdf
#
#
# Name: ProjectInitializationAutomation
# Owner: KalleHallden
# Stars: 592
# Repository: https://github.com/KalleHallden/ProjectInitializationAutomation
# Created: 2019-05-30T10:56:22Z
# Updated: 2023-06-07T18:52:51Z
# Description: None
#
#
# Name: multi-class-text-classification-cnn-rnn
# Owner: jiegzhan
# Stars: 590
# Repository: https://github.com/jiegzhan/multi-class-text-classification-cnn-rnn
# Created: 2016-10-28T16:55:06Z
# Updated: 2023-04-27T09:47:10Z
# Description: Classify Kaggle San Francisco Crime Description into 39 classes. Build the model with CNN, RNN (GRU and LSTM) and Word Embeddings on Tensorflow.
#
#
# Name: pyparallel
# Owner: pyparallel
# Stars: 578
# Repository: https://github.com/pyparallel/pyparallel
# Created: 2015-07-25T18:45:55Z
# Updated: 2023-05-09T08:23:53Z
# Description: Experimental multicore fork of Python 3
#
#
# Name: pushbullet.py
# Owner: richard-better
# Stars: 577
# Repository: https://github.com/richard-better/pushbullet.py
# Created: 2013-02-22T20:44:48Z
# Updated: 2023-05-09T13:17:19Z
# Description: A python client for http://pushbullet.com
#
#
# Name: python-twitter-examples
# Owner: ideoforms
# Stars: 576
# Repository: https://github.com/ideoforms/python-twitter-examples
# Created: 2011-11-30T16:00:38Z
# Updated: 2023-05-27T03:52:45Z
# Description: Examples of using Python for Twitter social data mining, using the python-twitter-tools framework.
#
#
# Name: OctaveConv_pytorch
# Owner: lxtGH
# Stars: 575
# Repository: https://github.com/lxtGH/OctaveConv_pytorch
# Created: 2019-04-16T15:25:18Z
# Updated: 2023-03-09T08:57:03Z
# Description: Pytorch implementation of newly added convolution

# %% [markdown]
# ### Visualizing Repositories Using Plotly

# %%
import requests

from plotly.graph_objects import Bar
from plotly import offline

# Make an API call and store the response
url = 'https://api.github.com/search/repositories?q=language:Python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Get names and stars data
response_dict = r.json()
repo_dicts = response_dict['items']

repo_names = []
stars = []
for repo_dict in repo_dicts:
    repo_names.append(repo_dict['name'])
    stars.append(repo_dict['stargazers_count'])

# Make visualization
data = [{
    'type': 'bar',
    'x': repo_names,
    'y': stars
}]

my_layout = {
    'title': 'Most-Starred Python Projects on Github',
    'xaxis': {'title': 'Repository'},
    'yaxis': {'title': 'Stars'}
}

fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename='python_repos.html')
# Out:
# Status code: 200
# 'python_repos.html'

# %% [markdown]
# ### Refining Plotly Charts

# %%
import requests

from plotly.graph_objects import Bar
from plotly import offline

# Make an API call and store the response
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Get names and stars data
response_dict = r.json()
repo_dicts = response_dict['items']

repo_names = []
stars = []
for repo_dict in repo_dicts:
    repo_names.append(repo_dict['name'])
    stars.append(repo_dict['stargazers_count'])

# Make visualization
data = [{
    'type': 'bar',
    'x': repo_names,
    'y': stars,
    'marker': {
        'color': 'rgb(60,100,150)',
        'line': {'width':1.5, 'color': 'rgb(25,25,25)'}
    },
    'opacity':0.6
}]

my_layout = {
    'title': 'Most-Starred Python Projects on Github',
    'titlefont':{'size':28},
    'xaxis': {'title': 'Repository', 'titlefont':{'size':24}, 'tickfont':{'size':14}},
    'yaxis': {'title': 'Stars', 'titlefont':{'size':24}, 'tickfont':{'size':14}}
}

fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename='python_repos.html')
# Out:
# Status code: 200
# 'python_repos.html'

# %% [markdown]
# ### Adding custom Tooltips

# %%
import requests

from plotly.graph_objects import Bar
from plotly import offline

# Make an API call and store the response
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Get names and stars data
response_dict = r.json()
repo_dicts = response_dict['items']

repo_names = []
stars = []
labels = []

for repo_dict in repo_dicts:
    repo_names.append(repo_dict['name'])
    stars.append(repo_dict['stargazers_count'])

    owner = repo_dict['owner']['login']
    description = repo_dict['description']
    label = f"{owner} <br /> {description}"
    labels.append(label)

# Make visualization
data = [{
    'type': 'bar',
    'x': repo_names,
    'y': stars,
    'hovertext':labels,
    'marker': {
        'color': 'rgb(60,100,150)',
        'line': {'width':1.5, 'color': 'rgb(25,25,25)'}
    },
    'opacity':0.6
}]

my_layout = {
    'title': 'Most-Starred Python Projects on Github',
    'titlefont':{'size':28},
    'xaxis': {'title': 'Repository', 'titlefont':{'size':24}, 'tickfont':{'size':14}},
    'yaxis': {'title': 'Stars', 'titlefont':{'size':24}, 'tickfont':{'size':14}}
}

fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename='python_repos.html')
# Out:
# Status code: 200
# 'python_repos.html'

# %% [markdown]
# ### Adding clickable links to graph

# %%
import requests

from plotly.graph_objects import Bar
from plotly import offline

# Make an API call and store the response
url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url, headers=headers)
print(f"Status code: {r.status_code}")

# Get names and stars data
response_dict = r.json()
repo_dicts = response_dict['items']

repo_links = []
stars = []
labels = []

for repo_dict in repo_dicts:
    repo_name = repo_dict['name']
    repo_url = repo_dict['html_url']
    repo_link = f"<a href='{repo_url}'>{repo_name}</a>"
    repo_links.append(repo_link)
    
    stars.append(repo_dict['stargazers_count'])

    owner = repo_dict['owner']['login']
    description = repo_dict['description']
    label = f"{owner} <br /> {description}"
    labels.append(label)

# Make visualization
data = [{
    'type': 'bar',
    'x': repo_links,
    'y': stars,
    'hovertext':labels,
    'marker': {
        'color': 'rgb(60,100,150)',
        'line': {'width':1.5, 'color': 'rgb(25,25,25)'}
    },
    'opacity':0.6
}]

my_layout = {
    'title': 'Most-Starred Python Projects on Github',
    'titlefont':{'size':28},
    'xaxis': {'title': 'Repository', 'titlefont':{'size':24}, 'tickfont':{'size':14}},
    'yaxis': {'title': 'Stars', 'titlefont':{'size':24}, 'tickfont':{'size':14}}
}

fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename='python_repos.html')
# Out:
# Status code: 200
# 'python_repos.html'

# %% [markdown]
# # The Hacker News API

# %%
import requests
import json

#Make an API call, and store the response
url = 'https://hacker-news.firebaseio.com/v0/item/19155826.json'
r = requests.get(url)
print(f"Status code: {r.status_code}")

# Explore the structure of the data
response_dict = r.json()
readablefile = 'readable_hn_data.json'
with open(readablefile, 'w') as f:
    json.dump(response_dict, f, indent=4)
# Out:
# Status code: 200

# %%
from operator import itemgetter
import requests
from plotly.graph_objects import Bar
from plotly import offline

# Make an API call and store the response
url = 'https://hacker-news.firebaseio.com/v0/topstories.json'
r = requests.get(url)
print(f"Status code: {r.status_code}")

# Process information about each submission
submission_ids = r.json()
submission_dicts = []

for submission_id in submission_ids[:30]:
    #Make a separate API call for each submission
    url = f"https://hacker-news.firebaseio.com/v0/item/{submission_id}.json"
    r = requests.get(url)
    print(f"id: {submission_id}\tstatus:{r.status_code}")
    response_dict = r.json()

    # Build a dictionary for each article
    submission_dict = {
        'title': response_dict['title'],
        'hn_link': f"httpL//news.ycombinator.com/item?id={submission_id}",
        'comments': response_dict['descendants']
    }
    submission_dicts.append(submission_dict)

submission_dicts = sorted(submission_dicts, key=itemgetter('comments'),reverse=True)


titles = []
links = []
comments = []
for submission_dict in submission_dicts:
    print(f"\nTitle: {submission_dict['title']}")
    print(f"Discussion link: {submission_dict['hn_link']}")
    print(f"Comments: {submission_dict['comments']}")

    title = submission_dict['title']
    link = f"<a href='{link}'>{title}</a>"
    comment = submission_dict['comments']

    titles.append(title)
    links.append(link)
    comments.append(comment)

data = [{
    'type':'bar',
    'x': titles,
    'y': comments,
    'hovertext': titles
}]

my_layout = {
    'title': 'Most Active Discussions on Hacker News',
    'xaxis': {'title': 'Labels'},
    'yaxis': {'title': 'Comments'}
}

fig = {'data':data, 'layout':my_layout}
offline.plot(fig, filename='active_discussion.html')
# Out:
# Status code: 200
# id: 36644274	status:200
# id: 36643630	status:200
# id: 36643670	status:200
# id: 36642315	status:200
# id: 36641782	status:200
# id: 36642796	status:200
# id: 36642867	status:200
# id: 36641393	status:200
# id: 36635373	status:200
# id: 36643211	status:200
# id: 36640148	status:200
# id: 36642825	status:200
# id: 36639530	status:200
# id: 36643278	status:200
# id: 36642932	status:200
# id: 36641226	status:200
# id: 36642012	status:200
# id: 36642935	status:200
# id: 36643732	status:200
# id: 36641607	status:200
# id: 36637655	status:200
# id: 36643325	status:200
# id: 36642799	status:200
# id: 36641542	status:200
# id: 36639932	status:200
# id: 36635526	status:200
# id: 36641423	status:200
# id: 36640769	status:200
# id: 36637221	status:200
# id: 36643212	status:200
#
# Title: Why I Hate Frameworks (2005)
# Discussion link: httpL//news.ycombinator.com/item?id=36637655
# Comments: 316
#
# Title: TypeScript please give us reflection/runtime types
# Discussion link: httpL//news.ycombinator.com/item?id=36637221
# Comments: 257
#
# Title: ProtonMail Rewrites Your Emails
# Discussion link: httpL//news.ycombinator.com/item?id=36639530
# Comments: 212
#
# Title: Meta releases Intermediate Graphics Library
# Discussion link: httpL//news.ycombinator.com/item?id=36635526
# Comments: 198
#
# Title: When did Alan Partridge first appear on television?
# Discussion link: httpL//news.ycombinator.com/item?id=36641782
# Comments: 108
#
# Title: If PEP 703 is accepted, Meta can commit three engineer-years to nogil CPython
# Discussion link: httpL//news.ycombinator.com/item?id=36643670
# Comments: 104
#
# Title: Owner of Symbolics Lisp machines IP is interested in a non-commercial release
# Discussion link: httpL//news.ycombinator.com/item?id=36635373
# Comments: 104
#
# Title: Matrix multiplication using only addition
# Discussion link: httpL//news.ycombinator.com/item?id=36640148
# Comments: 77
#
# Title: ZeroVer: 0-Based Versioning
# Discussion link: httpL//news.ycombinator.com/item?id=36641226
# Comments: 64
#
# Title: Google to explore alternatives to robots.txt
# Discussion link: httpL//news.ycombinator.com/item?id=36641607
# Comments: 61
#
# Title: Farmer ordered to pay $CAD82k after confusion over meaning of thumbs-up emoji
# Discussion link: httpL//news.ycombinator.com/item?id=36643278
# Comments: 56
#
# Title: The Horror Game of the Year Is a Doom II Mod
# Discussion link: httpL//news.ycombinator.com/item?id=36640769
# Comments: 55
#
# Title: Khoj: An AI Personal Assistant for Your Digital Brain
# Discussion link: httpL//news.ycombinator.com/item?id=36641542
# Comments: 52
#
# Title: Train an AI model once and deploy on any cloud
# Discussion link: httpL//news.ycombinator.com/item?id=36642315
# Comments: 50
#
# Title: I am drowning in mutes: The current Threads experience
# Discussion link: httpL//news.ycombinator.com/item?id=36642932
# Comments: 47
#
# Title: Frozen heads and bodies await revival at this Arizona cryonics facility
# Discussion link: httpL//news.ycombinator.com/item?id=36642012
# Comments: 39
#
# Title: LlamaIndex: Unleash the power of LLMs over your data
# Discussion link: httpL//news.ycombinator.com/item?id=36641393
# Comments: 26
#
# Title: Software Engineers Hate Code
# Discussion link: httpL//news.ycombinator.com/item?id=36642796
# Comments: 23
#
# Title: RISC-V Assembly Programming
# Discussion link: httpL//news.ycombinator.com/item?id=36641423
# Comments: 16
#
# Title: Scams upon scams: The data-driven advertising grift
# Discussion link: httpL//news.ycombinator.com/item?id=36643630
# Comments: 15
#
# Title: The ARM powered ThinkPad x13s, as a developer
# Discussion link: httpL//news.ycombinator.com/item?id=36642825
# Comments: 13
#
# Title: Super Drug
# Discussion link: httpL//news.ycombinator.com/item?id=36643212
# Comments: 11
#
# Title: The other fruit company, Apricot
# Discussion link: httpL//news.ycombinator.com/item?id=36643325
# Comments: 10
#
# Title: We all need some space
# Discussion link: httpL//news.ycombinator.com/item?id=36642799
# Comments: 6
#
# Title: How to Blow Up a Timeline
# Discussion link: httpL//news.ycombinator.com/item?id=36642935
# Comments: 4
#
# Title: Ford unleashes the UK’s first legal hands-free drive car – but who will buy it?
# Discussion link: httpL//news.ycombinator.com/item?id=36643732
# Comments: 4
#
# Title: Money No Enough, Passion Needed Too: Restoring Classic Singaporean Films
# Discussion link: httpL//news.ycombinator.com/item?id=36639932
# Comments: 2
#
# Title: Experiments with plane-filling curves and Fourier transform
# Discussion link: httpL//news.ycombinator.com/item?id=36643211
# Comments: 1
#
# Title: Going from React to Vanilla JavaScript
# Discussion link: httpL//news.ycombinator.com/item?id=36644274
# Comments: 0
#
# Title: Bevy XPBD: A physics engine for the Bevy game engine
# Discussion link: httpL//news.ycombinator.com/item?id=36642867
# Comments: 0
# 'active_discussion.html'

# %% [markdown]
# ### Hacker News Active Discussions Bar Chart

# %%
from operator import itemgetter

import requests

# Make an API call and store the response.
url = 'https://hacker-news.firebaseio.com/v0/topstories.json'
r = requests.get(url)
print(f"Status code: {r.status_code}")

# Process information about each submission.
submission_ids = r.json()
submission_dicts = []
for submission_id in submission_ids[:10]:
    # Make a separate API call for each submission.
    url = f"https://hacker-news.firebaseio.com/v0/item/{submission_id}.json"
    r = requests.get(url)
    print(f"id: {submission_id}\tstatus: {r.status_code}")
    response_dict = r.json()
    
    # Build a dictionary for each article.
    submission_dict = {
        'title': response_dict['title'],
        'hn_link': f"http://news.ycombinator.com/item?id={submission_id}",
        'comments': response_dict['descendants'],
    }
    submission_dicts.append(submission_dict)
    
submission_dicts = sorted(submission_dicts, key=itemgetter('comments'),
                            reverse=True)

for submission_dict in submission_dicts:
    print(f"\nTitle: {submission_dict['title']}")
    print(f"Discussion link: {submission_dict['hn_link']}")
    print(f"Comments: {submission_dict['comments']}")
# Out:
# Status code: 200
# id: 36643670	status: 200
# id: 36642315	status: 200
# id: 36643630	status: 200
# id: 36642932	status: 200
# id: 36642796	status: 200
# id: 36641393	status: 200
# id: 36635373	status: 200
# id: 36642867	status: 200
# id: 36640148	status: 200
# id: 36643211	status: 200
#
# Title: Owner of Symbolics Lisp machines IP is interested in a non-commercial release
# Discussion link: http://news.ycombinator.com/item?id=36635373
# Comments: 100
#
# Title: Matrix multiplication using only addition
# Discussion link: http://news.ycombinator.com/item?id=36640148
# Comments: 77
#
# Title: If PEP 703 is accepted, Meta can commit three engineer-years to nogil CPython
# Discussion link: http://news.ycombinator.com/item?id=36643670
# Comments: 60
#
# Title: Train an AI model once and deploy on any cloud
# Discussion link: http://news.ycombinator.com/item?id=36642315
# Comments: 47
#
# Title: I am drowning in mutes: The current Threads experience
# Discussion link: http://news.ycombinator.com/item?id=36642932
# Comments: 37
#
# Title: LlamaIndex: Unleash the power of LLMs over your data
# Discussion link: http://news.ycombinator.com/item?id=36641393
# Comments: 23
#
# Title: Software Engineers Hate Code
# Discussion link: http://news.ycombinator.com/item?id=36642796
# Comments: 15
#
# Title: Scams upon scams: The data-driven advertising grift
# Discussion link: http://news.ycombinator.com/item?id=36643630
# Comments: 2
#
# Title: Experiments with plane-filling curves and Fourier transform
# Discussion link: http://news.ycombinator.com/item?id=36643211
# Comments: 1
#
# Title: Bevy XPBD: A physics engine for the Bevy game engine
# Discussion link: http://news.ycombinator.com/item?id=36642867
# Comments: 0
